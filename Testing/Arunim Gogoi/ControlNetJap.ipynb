# %%
# Install required packages
# !pip install -q diffusers==0.24.0 transformers==4.41.0 accelerate==0.25.0 bitsandbytes==0.41.2
# !pip install -q gradio==4.1.1 pytorch-lightning==2.1.0
# !pip install -q controlnet_aux==0.0.7
# !pip install -q xformers==0.0.22
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 84.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 101.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 1.6 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# ...

# %%
# !pip install diffusers transformers accelerate safetensors datasets
# !pip install bitsandbytes xformers

# %%
from diffusers import StableDiffusionPipeline
import torch

# Load Stable Diffusion v1.5
model_id = "runwayml/stable-diffusion-v1-5"

# Load model
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.to("cuda")  # Move model to GPU
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.32.2",
#   "_name_or_path": "runwayml/stable-diffusion-v1-5",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
from IPython.display import display

prompt = "A traditional Japanese house floor plan"
image = pipe(prompt).images[0]

# Display the image
display(image)

# Save the image if needed
image.save("output.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
